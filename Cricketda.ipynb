# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv(r"C:\Users\maste\Desktop\data analyst\odi_1excel2.csv")

# %%
df
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0        SR Tendulkar   1989-2012  463   452  41  18426  200*  44.83  21367
# 1       KC Sangakkara   2000-2015  404   380  41  14234   169  41.98  18048
# 2          RT Ponting   1995-2012  375   365  39  13704   164  42.03  17046
# 3       ST Jayasuriya   1989-2011  445   433  18  13430   189  32.36  14725
# 4    DPMD Jayawardene   1998-2015  448   418  39  12650   144  33.37  16020
# ..                 ...        ...  ...   ...  ..    ...   ...    ...    ...
# 429           A Nehra   2001-2011  120    46  21    141    24   5.64    246
# 430     Rubel Hossain   2009-2019  101    52  24    140    17   5.00    249
# 431      EJ Chatfield   1979-1989  114    48  37    118   19*  10.72    346
# 432        GD McGrath   1993-2007  250    68  38    115    11   3.83    236
# 433         AA Donald   1991-2003  164    40  18     95    13   4.31    279
#
#         SR  100s  50s  0s       Country
# ...

# %%
df['Mat'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df["Runs"] = df["Runs"].astype(int)

# %%
df_grouped = df.groupby("Country")["Runs"].sum().reset_index()
df2=df_grouped.plot(kind="bar",xlabel="Country",ylabel="Runs",legend=False)
df3=df2.set_xticklabels(df_grouped["Country"])
df3
# Out:
# [Text(0, 0, 'Afganistan'),
#  Text(1, 0, 'Australia'),
#  Text(2, 0, 'Bangladesh'),
#  Text(3, 0, 'Canada'),
#  Text(4, 0, 'England'),
#  Text(5, 0, 'ICC/SA)'),
#  Text(6, 0, 'IRELAND'),
#  Text(7, 0, 'India'),
#  Text(8, 0, 'Kenya'),
#  Text(9, 0, 'Netherland'),
#  Text(10, 0, 'New Zealand'),
#  Text(11, 0, 'Pakistan'),
#  Text(12, 0, 'SCOT)'),
#  Text(13, 0, 'South Africa'),
#  Text(14, 0, 'Sri Lanka'),
#  Text(15, 0, 'UnitedStatesArab'),
#  Text(16, 0, 'West Indies'),
#  Text(17, 0, 'Zimbabwe')]

# %%
df2.plot(kind="pie")
# Out:
# []

# %%
df["HS_Status"] = df["HS"].apply(lambda x: " Not Out" if "*" in x else "out")
df
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0        SR Tendulkar   1989-2012  463   452  41  18426  200*  44.83  21367
# 1       KC Sangakkara   2000-2015  404   380  41  14234   169  41.98  18048
# 2          RT Ponting   1995-2012  375   365  39  13704   164  42.03  17046
# 3       ST Jayasuriya   1989-2011  445   433  18  13430   189  32.36  14725
# 4    DPMD Jayawardene   1998-2015  448   418  39  12650   144  33.37  16020
# ..                 ...        ...  ...   ...  ..    ...   ...    ...    ...
# 429           A Nehra   2001-2011  120    46  21    141    24   5.64    246
# 430     Rubel Hossain   2009-2019  101    52  24    140    17   5.00    249
# 431      EJ Chatfield   1979-1989  114    48  37    118   19*  10.72    346
# 432        GD McGrath   1993-2007  250    68  38    115    11   3.83    236
# 433         AA Donald   1991-2003  164    40  18     95    13   4.31    279
#
#         SR  100s  50s  0s       Country HS_Status
# ...

# %%
df_grouped = df.groupby(["Country","HS_Status"]).size().unstack()
df2=df_grouped
df2.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Country'>

# %%
import matplotlib.pyplot as plt
